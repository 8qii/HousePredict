# %%
from langchain_community.graphs import Neo4jGraph
import pandas as pd
import google.generativeai as genai
import numpy as np
import json
import torch
from torch_geometric.data import Data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[27], line 7
#       5 import json
#       6 import torch
# ----> 7 from torch_geometric.data import Data
#
# ModuleNotFoundError: No module named 'torch_geometric'

# %%
df = pd.read_csv("data/cleaned_house_prices_data.csv", nrows=5000)
print(df.head())
# Out:
#    Index                                              Title  \
# 0      0  1 BHK Ready to Occupy Flat for sale in Srushti...
# 1      1  2 BHK Ready to Occupy Flat for sale in Dosti V...
# 2      2  2 BHK Ready to Occupy Flat for sale in Sunrise...
# 3      4  2 BHK Ready to Occupy Flat for sale in TenX Ha...
# 4      5  1 BHK Ready to Occupy Flat for sale in Virat A...
#
#                                          Description  Amount(in rupees)  \
# 0  Bhiwandi, Thane has an attractive 1 BHK Flat f...          4200000.0
# 1  One can find this stunning 2 BHK flat for sale...          9800000.0
# 2  Up for immediate sale is a 2 BHK apartment in ...         14000000.0
# 3  This lovely 2 BHK Flat in Pokhran Road, Thane ...         16000000.0
# 4  Creatively planned and constructed is a 1 BHK ...          4500000.0
#
#    Price (in rupees) location         Status Transaction      Furnishing  \
# 0             6000.0    thane  Ready to Move      Resale     Unfurnished
# 1            13799.0    thane  Ready to Move      Resale  Semi-Furnished
# 2            17500.0    thane  Ready to Move      Resale     Unfurnished
# 3            18824.0    thane  Ready to Move      Resale     Unfurnished
# 4             6618.0    thane  Ready to Move      Resale     Unfurnished
#
#     facing Bathroom Balcony Car Parking             Ownership  Current Floor  \
# 0  Unknown        1       2           0               Unknown             10
# 1     East        2       0      1 Open              Freehold              3
# 2     East        2       0   1 Covered              Freehold             10
# 3     West        2       0   1 Covered  Co-operative Society             20
# 4     East        1       1           0  Co-operative Society              2
#
#    Total Floors
# 0            11
# 1            22
# 2            29
# 3            42
# 4             7

# %%
df['amount'] = df['Amount(in rupees)']
df['price'] = df['Price (in rupees)']
df = df.drop(columns=["Index", 'Amount(in rupees)', 'Price (in rupees)'])

# %%
for col in df.columns:
    print(col)
# Out:
# Title
# Description
# location
# Status
# Transaction
# Furnishing
# facing
# Bathroom
# Balcony
# Car Parking
# Ownership
# Current Floor
# Total Floors
# amount
# price

# %%
df.columns = (
    df.columns.str.lower() # Chuyển về chữ thường
    .str.replace(" ", "_") # Thay khoảng trắng bằng dấu gạch dưới (_)
    .str.replace(r"\(.*\)", "", regex=True) # Xóa nội dung trong ngoặc
)

# %%
NEO4J_URL = "bolt://localhost:7687"
NEO4J_USERNAME = "neo4j"
NEO4J_PASSWORD = "hqiineo4j"
NEO4J_DATABASE = "neo4j"

graph = Neo4jGraph(
    url=NEO4J_URL,
    username=NEO4J_USERNAME,
    password=NEO4J_PASSWORD,
    database=NEO4J_DATABASE
)

print("okay")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14688\3045156017.py:6: LangChainDeprecationWarning: The class `Neo4jGraph` was deprecated in LangChain 0.3.8 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-neo4j package and should be used instead. To use it run `pip install -U :class:`~langchain-neo4j` and import as `from :class:`~langchain_neo4j import Neo4jGraph``.
#   graph = Neo4jGraph(
# okay

# %%
def insert_data(title, description, amount, price, location, status, transaction, furnishing, facing, bathroom, balcony, car_parking, ownership, current_floor, total_floors):
    query = """
    MERGE (h:House {title: $title})
    SET h.description = $description,
        h.amount = $amount,
        h.price = $price
    
    MERGE (l:Location {name: $location})
    MERGE (h)-[:LOCATED_IN]->(l)
    
    MERGE (o:Ownership {name: $ownership})
    MERGE (h)-[:HAS_OWNERSHIP]->(o)
    
    MERGE (s:Status {name: $status})
    MERGE (h)-[:HAS_STATUS]->(s)
    
    MERGE (t:Transaction {name: $transaction})
    MERGE (h)-[:HAS_TRANSACTION]->(t)
    
    MERGE (f:Furnishing {name: $furnishing})
    MERGE (h)-[:HAS_FURNISHING]->(f)
    
    MERGE (fc:Facing {name: $facing})
    MERGE (h)-[:HAS_FACING]->(fc)
    
    MERGE (b:Bathroom {name: $bathroom})
    MERGE (h)-[:HAS_BATHROOM]->(b)
    
    MERGE (ba:Balcony {name: $balcony})
    MERGE (h)-[:HAS_BALCONY]->(ba)
    
    MERGE (cp:CarParking {name: $car_parking})
    MERGE (h)-[:HAS_CAR_PARKING]->(cp)
    
    MERGE (cf:CurrentFloor {name: $current_floor})
    MERGE (h)-[:HAS_CURRENT_FLOOR]->(cf)
    
    MERGE (tf:TotalFloors {name: $total_floors})
    MERGE (h)-[:HAS_TOTAL_FLOORS]->(tf)
    """

    graph.query(query, params={
        "title": title, 
        "description": description, 
        "amount": amount, 
        "price": price, 
        "location": location, 
        "status": status, 
        "transaction": transaction, 
        "furnishing": furnishing, 
        "facing": facing, 
        "bathroom": bathroom, 
        "balcony": balcony, 
        "car_parking": car_parking, 
        "ownership": ownership, 
        "current_floor": current_floor, 
        "total_floors": total_floors
    })

print("✅ Dữ liệu đã nhập vào Neo4j!")
# Out:
# ✅ Dữ liệu đã nhập vào Neo4j!

# %%
# Cấu hình Gemini API
genai.configure(api_key="AIzaSyAmLesw2keGhIrZPMEyYJUs1PUqIidIWFU")

# Khởi tạo model Gemini
model = genai.GenerativeModel("gemini-2.0-flash")

# # Hàm trích xuất thực thể từ câu hỏi
# def extract_entities(question):
#     prompt = f"Trích xuất các thực thể quan trọng từ câu hỏi: '{question}'. Chỉ trả về danh sách thực thể, không thêm bất kỳ văn bản nào khác. Ưu tiên tính liên kết và thông nhất của thực thể"
#     response = model.generate_content(prompt)
    
#     if response and response.text:
#         return response.text.strip().split(", ")
#     else:
#         return []

# %%
def get_all_entities(tx):
    query = """
    MATCH (n) RETURN DISTINCT n.name AS entity
    """
    result = tx.run(query)
    return [record["entity"] for record in result if record["entity"]]

with driver.session() as session:
    entity_list = session.read_transaction(get_all_entities)

print(f"✅ Lấy {len(entity_list)} thực thể từ Knowledge Graph")

# %%
# user_input = "i want to buy a 2 BHK Ready to Occupy Flat that located in thane and have 2 bathrooms"
# extract_entities(user_input)

# %%
# !pip install rapidfuzz

# %%
# from rapidfuzz import process, fuzz

# def find_top_matches(extracted_entities, entity_dict, top_n=5, threshold=10):
#     """
#     Tìm top_n thực thể gần nhất cho từng thực thể trích xuất.
#     Trả về danh sách các thực thể tương đồng với % độ giống nhau.
#     """
#     results = {}  # Lưu kết quả theo từng thực thể trích xuất

#     entity_names = [str(name) for name in entity_dict.keys()]  # Lấy danh sách tên thực thể

#     for entity in extracted_entities:
#         entity = str(entity)  # Đảm bảo entity là chuỗi

#         matches = process.extract(entity, entity_names, scorer=fuzz.token_sort_ratio, limit=top_n)

#         # Lọc các thực thể có độ tương đồng >= threshold
#         filtered_matches = [(match, score, entity_dict[match]) for match, score, _ in matches if score >= threshold]

#         if filtered_matches:
#             results[entity] = filtered_matches  # Lưu danh sách thực thể gần nhất

#     return results

# find_best_matches(extract_entities(user_input), entity_dict=entity_dict)

# %%
# user_input = "2 BHK Ready to Occupy Flat, thane, 2 bathrooms"

# # 1️⃣ Trích xuất thực thể từ LLM
# extracted_entities = extract_entities(user_input)  # Trích xuất thực thể

# # 2️⃣ Tìm kiếm 5 thực thể gần nhất cho từng thực thể
# top_matches = find_top_matches(extracted_entities, entity_dict, top_n=5, threshold=10)

# # 3️⃣ Hiển thị kết quả
# for entity, matches in top_matches.items():
#     print(f"📌 **Thực thể trích xuất**: {entity}")
#     for match, score, entity_type in matches:
#         print(f"   🔹 {match} ({entity_type}) - {score}% giống nhau")
#     print()

# %%
# import json

# # Đọc schema từ file JSON
# with open("data/schema.json", "r", encoding="utf-8") as f:
#     schema = json.load(f)

# def generate_cypher_prompt(text):
#     CYPHER_GENERATION_TEMPLATE = f"""Nhiệm vụ: Tạo một truy vấn Cypher để truy vấn cơ sở dữ liệu đồ thị Neo4j.
#         Hướng dẫn:
#         - Phân tích câu hỏi và trích xuất các thành phần đồ thị liên quan một cách linh hoạt. Sử dụng thông tin này để xây dựng truy vấn Cypher.
#         - Chỉ sử dụng các loại quan hệ và thuộc tính từ sơ đồ đã cung cấp. Không bao gồm bất kỳ loại quan hệ hoặc thuộc tính nào khác.
#         - Sơ đồ được xây dựng dựa trên cấu trúc đồ thị với các nút và quan hệ như sau:
#         {json.dumps(schema, indent=4, ensure_ascii=False)}
#         - Chỉ trả về truy vấn Cypher đã được tạo trong phản hồi của bạn. Không bao gồm giải thích, chú thích hoặc bất kỳ văn bản bổ sung nào khác. 
#         - Đảm bảo truy vấn Cypher phản hồi chính xác câu hỏi được đưa ra theo đúng sơ đồ.

#         câu cần bạn sinh truy vấn là:
#         {text}
#     """

#     response = model.generate_content(CYPHER_GENERATION_TEMPLATE)
#     return response.text

# %%
# client_message = "i want to buy a 1 BHK Ready to Occupy Flat for sale in Srushti that have 2 bathrooms and face to the west"
# cypher_result = generate_cypher_prompt(client_message)
# print(cypher_result)
# def clean_cypher_code(code: str) -> str:
#     return code.replace("```cypher", "").replace("```", "").strip()

# cypher_result = clean_cypher_code(cypher_result)
# cypher_result
# Out:
# ```cypher
# MATCH (h:House)-[:HAS_BATHROOM]->(b:Bathroom {`Bathroom`: "2"})
# MATCH (h)-[:HAS_STATUS]->(s:Status {`Status`: "Ready to Move"})
# MATCH (h)-[:HAS_FACING]->(f:Facing {`Facing`: "West"})
# MATCH (h)-[:LOCATED_IN]->(l:Location)
# WHERE l.Location = "thane"
# RETURN h
# ```
# 'MATCH (h:House)-[:HAS_BATHROOM]->(b:Bathroom {`Bathroom`: "2"})\nMATCH (h)-[:HAS_STATUS]->(s:Status {`Status`: "Ready to Move"})\nMATCH (h)-[:HAS_FACING]->(f:Facing {`Facing`: "West"})\nMATCH (h)-[:LOCATED_IN]->(l:Location)\nWHERE l.Location = "thane"\nRETURN h'

# %%
# result = graph.query(cypher_result)
# result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 result = graph.query(cypher_result)
#       2 result
#
# NameError: name 'graph' is not defined

# %%
def house_predict_prompt(row):
    prompt_template = f"""Dưới đây là thông tin về một căn nhà, hãy ước tính giá bán dựa trên dữ liệu thị trường hiện tại theo đơn vị INR.  
    Chỉ trả về một con số duy nhất là giá nhà (không giải thích, không kèm theo ký tự khác).  

    Thông tin căn nhà:  
    - **Vị trí:** {row['location']}  
    - **Trạng thái:** {row['status']}  
    - **Loại giao dịch:** {row['transaction']}  
    - **Nội thất:** {row['furnishing']}  
    - **Hướng nhà:** {row['facing']}  
    - **Số phòng tắm:** {row['bathroom']}  
    - **Số ban công:** {row['balcony']}  
    - **Chỗ để xe:** {row['car_parking']}  
    - **Quyền sở hữu:** {row['ownership']}  
    - **Tầng hiện tại:** {row['current_floor']}  
    - **Tổng số tầng:** {row['total_floors']}  

    Dưới đây là thông tin ví dụ về một số căn nhà và giá của chúng:\n\n
    """

    # Chọn ví dụ từ dataset làm dữ liệu Few-shot learning
    examples = df.sample(40).to_dict(orient="records")

    for ex in examples:
        prompt_template += f"- **Vị trí:** {ex['location']}, **Trạng thái:** {ex['status']}, **Loại giao dịch:** {ex['transaction']}, **Nội thất:** {ex['furnishing']}, **Hướng:** {ex['facing']}, **Phòng tắm:** {ex['bathroom']}, **Ban công:** {ex['balcony']}, **Chỗ để xe:** {ex['car_parking']}, **Quyền sở hữu:** {ex['ownership']}, **Tầng hiện tại:** {ex['current_floor']}, **Tổng tầng:** {ex['total_floors']}, **Giá nhà:** {ex['amount']} \n\n"
    

    prompt_template += "Vui lòng dự đoán giá nhà và chỉ trả về một con số duy nhất, không kèm theo văn bản hoặc ký tự nào khác."

    response = model.generate_content(prompt_template)
    return response.text

# %%
df
# Out:
#                                                  title  \
# 0    1 BHK Ready to Occupy Flat for sale in Srushti...
# 1    2 BHK Ready to Occupy Flat for sale in Dosti V...
# 2    2 BHK Ready to Occupy Flat for sale in Sunrise...
# 3    2 BHK Ready to Occupy Flat for sale in TenX Ha...
# 4    1 BHK Ready to Occupy Flat for sale in Virat A...
# ..                                                 ...
# 195  2 BHK Ready to Occupy Flat for sale in Hiranan...
# 196  2 BHK Ready to Occupy Flat for sale in Samrin ...
# 197  2 BHK Ready to Occupy Flat for sale in And For...
# 198  2 BHK Ready to Occupy Flat for sale Bhaskar Co...
# 199  3 BHK Ready to Occupy Flat for sale in Project...
#
#                                            description location  \
# 0    Bhiwandi, Thane has an attractive 1 BHK Flat f...    thane
# 1    One can find this stunning 2 BHK flat for sale...    thane
# 2    Up for immediate sale is a 2 BHK apartment in ...    thane
# 3    This lovely 2 BHK Flat in Pokhran Road, Thane ...    thane
# 4    Creatively planned and constructed is a 1 BHK ...    thane
# ..                                                 ...      ...
# 195  Carefully laid out in the prime location of Hi...    thane
# 196  This exquisite 2 BHK Flat is offered for sale ...    thane
# 197  One can find this stunning 2 BHK flat for sale...    thane
# 198  This ready to move-in 2 BHK flat is available ...    thane
# 199  This beautiful 3 BHK Flat is available for sal...    thane
#
#             status   transaction      furnishing        facing bathroom  \
# 0    Ready to Move        Resale     Unfurnished       Unknown        1
# 1    Ready to Move        Resale  Semi-Furnished          East        2
# 2    Ready to Move        Resale     Unfurnished          East        2
# 3    Ready to Move        Resale     Unfurnished          West        2
# 4    Ready to Move        Resale     Unfurnished          East        1
# ..             ...           ...             ...           ...      ...
# 195  Ready to Move        Resale  Semi-Furnished  North - East        2
# 196  Ready to Move  New Property     Unfurnished  North - East        2
# 197  Ready to Move        Resale  Semi-Furnished          East        2
# 198  Ready to Move  New Property     Unfurnished          East        2
# 199  Ready to Move        Resale  Semi-Furnished          West        3
#
#     balcony car_parking             ownership  current_floor  total_floors  \
# 0         2           0               Unknown             10            11
# 1         0      1 Open              Freehold              3            22
# 2         0   1 Covered              Freehold             10            29
# 3         0   1 Covered  Co-operative Society             20            42
# 4         1           0  Co-operative Society              2             7
# ..      ...         ...                   ...            ...           ...
# 195       0      1 Open              Freehold              5            14
# 196       1   1 Covered              Freehold              2            29
# 197       3           0              Freehold              7            19
# 198       2   1 Covered              Freehold              4            30
# 199       0  1 Covered,              Freehold             12            27
#
#          amount    price
# 0     4200000.0   6000.0
# 1     9800000.0  13799.0
# 2    14000000.0  17500.0
# 3    16000000.0  18824.0
# 4     4500000.0   6618.0
# ..          ...      ...
# 195  16500000.0  16517.0
# 196  15900000.0  22053.0
# 197   6300000.0   7545.0
# 198  19300000.0  14846.0
# 199  29900000.0  19933.0
#
# [200 rows x 15 columns]

# %%
row = df.iloc[50]
print(f"Giá nhà thực tế: {row['amount']}")
predicted_price = house_predict_prompt(row)
print(f"Giá nhà dự đoán: {predicted_price}")
# Out:
# Giá nhà thực tế: 10000000.0
# Giá nhà dự đoán: 6500000
